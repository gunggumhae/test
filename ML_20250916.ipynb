# %%
# !unzip mortDefault1.zip
# Out:
# Archive:  mortDefault1.zip
#   inflating: mortDefault.csv

# %%
import pandas as pd
df= pd.read_csv("mortDefault.csv")
# Out:
# /tmp/ipython-input-2804469966.py:2: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df= pd.read_csv("mortDefault.csv")

# %%
import numpy as np
df[ "creditScore"] = df.creditScore.replace("qqq",np.nan).replace("@@@", np.nan)
#df.creditScore.replace(["qqq", "@@@@"], [np.nan, np.nan], inplace=True)
df.isnull().mean()
df.dropna(inplace=True) #df.fillna(0)

# %%
df["creditScore"] = df.creditScore.astype("int")
df.drop( "year", axis=1, inplace=True )

# %%
from sklearn.model_selection import train_test_split
train, test = train_test_split(df)

# %%
df.default.value_counts()/999995

# %%
from sklearn.preprocessing import MinMaxScaler
scaled = MinMaxScaler().fit_transform(   df.drop("default", axis=1)  )
df_scaled = pd.DataFrame( scaled, columns=df.columns[0:4])
df_scaled
# Out:
#         creditScore  houseAge  yearsEmploy    ccDebt
# 0          0.357873     0.500     0.533333  0.301848
# 1          0.370143     0.275     0.466667  0.383915
# 2          0.646217     0.425     0.266667  0.496235
# 3          0.501022     0.550     0.333333  0.257426
# 4          0.451943     0.375     0.400000  0.461739
# ...             ...       ...          ...       ...
# 999990     0.312883     0.725     0.266667  0.231554
# 999991     0.374233     0.425     0.333333  0.478303
# 999992     0.400818     0.250     0.600000  0.452019
# 999993     0.770961     0.325     0.200000  0.111088
# 999994     0.447853     0.600     0.266667  0.359206
#
# [999995 rows x 4 columns]
